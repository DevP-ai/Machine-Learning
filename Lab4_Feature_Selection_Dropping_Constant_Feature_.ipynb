# %% [markdown]
# <a href="https://colab.research.google.com/github/DevP-ai/Machine-Learning/blob/master/Lab4_Feature_Selection_Dropping_Constant_Feature_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # **Dropping Constant Feature**

# %%
data=pd.DataFrame({"A":[1,2,4,1,2,4],
                   "B":[4,5,6,7,8,9],
                   "C":[0,0,0,0,0,0],
                   "D":[1,1,1,1,1,1]})

# %%
data
# Out:
#    A  B  C  D
# 0  1  4  0  1
# 1  2  5  0  1
# 2  4  6  0  1
# 3  1  7  0  1
# 4  2  8  0  1
# 5  4  9  0  1

# %% [markdown]
# ## **Variance Threshold**

# %%
## It will remove Zero Variance Features

from sklearn.feature_selection import VarianceThreshold
var_thres=VarianceThreshold(threshold=0)
var_thres.fit(data)
# Out:
# VarianceThreshold(threshold=0)

# %%
var_thres.get_support()
# Out:
# array([ True,  True, False, False])

# %%
data.columns[var_thres.get_support()]
# Out:
# Index(['A', 'B'], dtype='object')

# %%
const_columns=[column for column in data.columns 
               if column not in data.columns[var_thres.get_support()]]

# %%
const_columns
# Out:
# ['C', 'D']

# %%
data.drop(const_columns,axis=1)
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  4  6
# 3  1  7
# 4  2  8
# 5  4  9

# %% [markdown]
# ## **Try in Bigger Dataset**

# %%
df=pd.read_csv("/content/santarder.csv",nrows=100)

# %%
df.sample(5)
# Out:
#      ID  var3  var15  imp_ent_var16_ult1  imp_op_var39_comer_ult1  \
# 32   80     2     26                   0                     0.00
# 76  154     2     72                   0                     0.00
# 31   77     2     66                   0                     0.00
# 61  136     2     41                 525                   353.97
# 73  151     2     24                   0                     0.00
#
#     imp_op_var39_comer_ult3  imp_op_var40_comer_ult1  imp_op_var40_comer_ult3  \
# 32                     0.00                      0.0                      0.0
# 76                     0.00                      0.0                      0.0
# 31                     0.00                      0.0                      0.0
# 61                   390.81                      0.0                      0.0
# 73                     0.00                      0.0                      0.0
#
#     imp_op_var40_efect_ult1  imp_op_var40_efect_ult3  ...  \
# ...

# %%
df.shape
# Out:
# (100, 371)

# %%
X=df.drop(labels=['TARGET'],axis=1)
y=df['TARGET']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,
                                               random_state=0)

# %%
X_train.shape,X_test.shape
# Out:
# ((70, 370), (30, 370))

# %%
var_thres=VarianceThreshold(threshold=0)
var_thres.fit(X_train)
# Out:
# VarianceThreshold(threshold=0)

# %%
var_thres.get_support()
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True, False,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True, False,  True,  True, False, False,  True,  True, False,
#        False,  True,  True,  True,  True,  True,  True,  True, False,
#        False, False, False,  True,  True, False,  True,  True, False,
#        False, False,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True, False, False, False, False, False, False,
#         True,  True,  True,  True, False, False, False, False, False,
#        False, False,  True,  True,  True,  True,  True,  True,  True,
#        False,  True, False, False, False, False,  True,  True,  True,
#         True,  True, False, False,  True,  True,  True,  True,  True,
#         True,  True, False, False, False, False,  True,  True, False,
#         True,  True, False, False,  True,  True,  True,  True,  True,
# ...

# %%
const_columns=[column for column in X_train.columns
               if column not in X_train.columns[var_thres.get_support()]]

# %%
print(const_columns)
# Out:
# ['imp_op_var40_efect_ult1', 'imp_sal_var16_ult1', 'ind_var2_0', 'ind_var2', 'ind_var6_0', 'ind_var6', 'ind_var13_largo_0', 'ind_var13_largo', 'ind_var13_medio_0', 'ind_var13_medio', 'ind_var14', 'ind_var18_0', 'ind_var18', 'ind_var19', 'ind_var27_0', 'ind_var28_0', 'ind_var28', 'ind_var27', 'ind_var29_0', 'ind_var29', 'ind_var32_cte', 'ind_var32_0', 'ind_var32', 'ind_var33_0', 'ind_var33', 'ind_var34_0', 'ind_var34', 'ind_var41', 'ind_var44_0', 'ind_var44', 'ind_var46_0', 'ind_var46', 'num_var6_0', 'num_var6', 'num_var13_largo_0', 'num_var13_largo', 'num_var13_medio_0', 'num_var13_medio', 'num_var14', 'num_var18_0', 'num_var18', 'num_op_var40_hace3', 'num_var27_0', 'num_var28_0', 'num_var28', 'num_var27', 'num_var29_0', 'num_var29', 'num_var32_0', 'num_var32', 'num_var33_0', 'num_var33', 'num_var34_0', 'num_var34', 'num_var41', 'num_var44_0', 'num_var44', 'num_var46_0', 'num_var46', 'saldo_var6', 'saldo_var13_largo', 'saldo_var13_medio', 'saldo_var14', 'saldo_var18', 'saldo_var28', '
# ...

# %%
X_train.drop(const_columns,axis=1)
# Out:
#      ID  var3  var15  imp_ent_var16_ult1  imp_op_var39_comer_ult1  \
# 60  135     2     38                   0                   477.06
# 80  159     2     45                   0                    26.97
# 90  173     0      5                   0                     0.00
# 68  144     2     23                   0                     0.00
# 51  115     2     22                   0                     0.00
# ..  ...   ...    ...                 ...                      ...
# 96  180     2     23                   0                     0.00
# 67  143     2     23                   0                     0.00
# 64  140     2     25                   0                     0.00
# 47  107     2     42                   0                     0.00
# 44  102     2     62                   0                     0.00
#
#     imp_op_var39_comer_ult3  imp_op_var40_comer_ult1  imp_op_var40_comer_ult3  \
# 60                   618.36                      0.0                      0.0
# ...
