# %% [markdown]
# <a href="https://colab.research.google.com/github/DevP-ai/Machine-Learning/blob/master/MLA_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/all_data.csv',header=None)

# %%
df.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0 -0.000133  0.000262  0.001099  0.001834  0.002109  0.002223  0.002233
# 1 -0.000842 -0.001011 -0.001071 -0.000944 -0.000794 -0.000610 -0.000445
# 2 -0.000766 -0.000535  0.000162  0.000898  0.001287  0.001582  0.001704
# 3 -0.000301 -0.000377 -0.000451 -0.000529 -0.000685 -0.000845 -0.000899
# 4 -0.000589 -0.000857 -0.001135 -0.001171 -0.001128 -0.001039 -0.000959
#
#         7         8         9    ...      527     528     529     530  \
# 0  0.002036  0.001582  0.000969  ...  0.82953  2.9079  3.7557  1.3344
# 1 -0.000173  0.000077  0.000285  ...  0.84335  3.0110  3.9877  1.2461
# 2  0.001659  0.001574  0.001438  ...  0.87413  3.0613  3.9749  1.1560
# 3 -0.000822 -0.000550 -0.000182  ...  0.85467  3.3337  3.9205  1.3341
# 4 -0.000937 -0.000916 -0.000819  ...  0.82978  3.5814  3.7667  1.1151
#
#        531      532      533     534      535  536
# 0  0.74247  0.22507  0.56249  1.5705  0.79906    0
# ...

# %%
df.isnull().sum()
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 532    0
# 533    0
# 534    0
# 535    0
# 536    0
# Length: 537, dtype: int64

# %%
df.describe()
# Out:
#               0           1           2           3           4           5    \
# count  230.000000  230.000000  230.000000  230.000000  230.000000  230.000000
# mean    -0.000450   -0.000537   -0.000542   -0.000417   -0.000302   -0.000170
# std      0.001384    0.002011    0.003154    0.003986    0.004287    0.004390
# min     -0.004177   -0.005409   -0.006209   -0.006735   -0.007215   -0.007269
# 25%     -0.001160   -0.001518   -0.002534   -0.003125   -0.003293   -0.003024
# 50%     -0.000793   -0.000933   -0.001141   -0.001402   -0.001455   -0.001362
# 75%     -0.000309   -0.000405    0.000426    0.001461    0.001823    0.002050
# max      0.006799    0.008477    0.010620    0.013078    0.013870    0.013917
#
#               6           7           8           9    ...         527  \
# count  230.000000  230.000000  230.000000  230.000000  ...  230.000000
# mean    -0.000037    0.000106    0.000245    0.000386  ...    0.819352
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of           0         1         2         3         4         5         6    \
# 0   -0.000133  0.000262  0.001099  0.001834  0.002109  0.002223  0.002233
# 1   -0.000842 -0.001011 -0.001071 -0.000944 -0.000794 -0.000610 -0.000445
# 2   -0.000766 -0.000535  0.000162  0.000898  0.001287  0.001582  0.001704
# 3   -0.000301 -0.000377 -0.000451 -0.000529 -0.000685 -0.000845 -0.000899
# 4   -0.000589 -0.000857 -0.001135 -0.001171 -0.001128 -0.001039 -0.000959
# ..        ...       ...       ...       ...       ...       ...       ...
# 225 -0.000978 -0.001481 -0.002011 -0.001986 -0.001594 -0.001217 -0.000997
# 226 -0.001599 -0.001084  0.000465  0.002076  0.002883  0.003667  0.004457
# 227 -0.000511 -0.001370 -0.002769 -0.003582 -0.003714 -0.003721 -0.003621
# 228 -0.000880 -0.001734 -0.003095 -0.003891 -0.004015 -0.003949 -0.003827
# 229 -0.001599 -0.001084  0.000465  0.002076  0.002883  0.003667  0.004457
#
# ...

# %%
df.shape
# Out:
# (230, 537)

# %%
import numpy as np

# %%
X=df.iloc[:,:-1]

# %%
X
# Out:
#           0         1         2         3         4         5         6    \
# 0   -0.000133  0.000262  0.001099  0.001834  0.002109  0.002223  0.002233
# 1   -0.000842 -0.001011 -0.001071 -0.000944 -0.000794 -0.000610 -0.000445
# 2   -0.000766 -0.000535  0.000162  0.000898  0.001287  0.001582  0.001704
# 3   -0.000301 -0.000377 -0.000451 -0.000529 -0.000685 -0.000845 -0.000899
# 4   -0.000589 -0.000857 -0.001135 -0.001171 -0.001128 -0.001039 -0.000959
# ..        ...       ...       ...       ...       ...       ...       ...
# 225 -0.000978 -0.001481 -0.002011 -0.001986 -0.001594 -0.001217 -0.000997
# 226 -0.001599 -0.001084  0.000465  0.002076  0.002883  0.003667  0.004457
# 227 -0.000511 -0.001370 -0.002769 -0.003582 -0.003714 -0.003721 -0.003621
# 228 -0.000880 -0.001734 -0.003095 -0.003891 -0.004015 -0.003949 -0.003827
# 229 -0.001599 -0.001084  0.000465  0.002076  0.002883  0.003667  0.004457
#
#           7         8         9    ...      526      527     528     529  \
# ...

# %%
y=df.iloc[:,-1]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 225    1
# 226    1
# 227    1
# 228    1
# 229    1
# Name: 536, Length: 230, dtype: int64

# %%
X=np.array(X).T

# %%
X=pd.DataFrame(X)

# %%
X[0]
# Out:
# 0     -0.000133
# 1      0.000262
# 2      0.001099
# 3      0.001834
# 4      0.002109
#          ...
# 531    0.742470
# 532    0.225070
# 533    0.562490
# 534    1.570500
# 535    0.799060
# Name: 0, Length: 536, dtype: float64

# %%
X.describe()
# Out:
#               0           1           2           3           4           5    \
# count  536.000000  536.000000  536.000000  536.000000  536.000000  536.000000
# mean     0.025111    0.025813    0.024400    0.025106    0.024145    0.023868
# std      0.234115    0.243869    0.238624    0.248882    0.244564    0.246637
# min     -0.026893   -0.021074   -0.029054   -0.021758   -0.022622   -0.024228
# 25%     -0.000102   -0.000056   -0.000059   -0.000182   -0.000088   -0.000101
# 50%      0.000027    0.000031    0.000020   -0.000001    0.000009    0.000013
# 75%      0.000463    0.000569    0.000492    0.000117    0.000248    0.000123
# max      3.755700    3.987700    3.974900    3.920500    3.766700    4.113400
#
#               6           7           8           9    ...         220  \
# count  536.000000  536.000000  536.000000  536.000000  ...  536.000000
# mean     0.028022    0.027250    0.026872    0.028124  ...    0.030772
# ...

# %%
X.shape
# Out:
# (536, 230)

# %%
mean=X.describe().iloc[1]

# %%
min=X.describe().iloc[3]

# %%
max=X.describe().iloc[7]

# %%
x=[mean,min,max]

# %%
x=pd.DataFrame(x)

# %%
x
# Out:
#            0         1         2         3         4         5         6    \
# mean  0.025111  0.025813  0.024400  0.025106  0.024145  0.023868  0.028022
# min  -0.026893 -0.021074 -0.029054 -0.021758 -0.022622 -0.024228 -0.016639
# max   3.755700  3.987700  3.974900  3.920500  3.766700  4.113400  3.541700
#
#            7         8         9    ...       220       221       222  \
# mean  0.027250  0.026872  0.028124  ...  0.030772  0.032996  0.033013
# min  -0.025508 -0.026207 -0.020987  ... -0.006483 -0.007598 -0.007825
# max   3.850600  3.731600  3.841300  ...  3.475200  3.811600  3.746700
#
#            223       224       225       226       227       228       229
# mean  0.035067  0.034949  0.034311  0.031896  0.032878  0.034118  0.031896
# min  -0.010164 -0.009480 -0.010830 -0.004494 -0.003721 -0.006268 -0.004494
# max   3.887000  3.645600  3.840500  3.704900  3.590500  3.959800  3.704900
#
# [3 rows x 230 columns]

# %%
x=np.array(x).T

# %%
column_names=["mean","min",'max']

# %%
feature=pd.DataFrame(x,columns=column_names)

# %%
feature
# Out:
#          mean       min     max
# 0    0.025111 -0.026893  3.7557
# 1    0.025813 -0.021074  3.9877
# 2    0.024400 -0.029054  3.9749
# 3    0.025106 -0.021758  3.9205
# 4    0.024145 -0.022622  3.7667
# ..        ...       ...     ...
# 225  0.034311 -0.010830  3.8405
# 226  0.031896 -0.004494  3.7049
# 227  0.032878 -0.003721  3.5905
# 228  0.034118 -0.006268  3.9598
# 229  0.031896 -0.004494  3.7049
#
# [230 rows x 3 columns]

# %%
feature.shape
# Out:
# (230, 3)

# %%
y.shape
# Out:
# (230,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(feature,y, test_size = 0.25, random_state = 0)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report
cm = confusion_matrix(y_test, y_pred)
  
print ("Confusion Matrix : \n", cm)
# Out:
# Confusion Matrix :
#  [[18  8]
#  [12 20]]

# %%
from sklearn.metrics import accuracy_score
print ("Accuracy : ", accuracy_score(y_test, y_pred))
# Out:
# Accuracy :  0.6551724137931034

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.69      0.64        26
#            1       0.71      0.62      0.67        32
#
#     accuracy                           0.66        58
#    macro avg       0.66      0.66      0.65        58
# weighted avg       0.66      0.66      0.66        58

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.plot(df[0])
plt.subplot(2,2,2)
plt.plot(df[300])
plt.show()
