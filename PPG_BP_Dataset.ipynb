# %% [markdown]
# <a href="https://colab.research.google.com/github/DevP-ai/Machine-Learning/blob/master/PPG_BP_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/content/PPG-BP dataset  0111.csv")

# %%
df.sample(5)
# Out:
#      Num.  subject_ID Sex(M/F)  Age(year)  Height(cm)  Weight(kg)  \
# 80     81         115   Female         54         150          82
# 206   207         406   Female         26         171          75
# 63     64          95   Female         64         163          72
# 77     78         112     Male         61         165          66
# 201   202         257   Female         28         160          58
#
#      Systolic Blood Pressure(mmHg)  Diastolic Blood Pressure(mmHg)  \
# 80                             108                              66
# 206                            106                              63
# 63                             153                              71
# 77                             173                             100
# 201                            122                              70
#
#      Heart Rate(b/m)  BMI(kg/m^2)          Hypertension
# 80                62        36.44                     0
# ...

# %%
df['Hypertension'].replace({'Normal':'00'},inplace=True)
df['Hypertension'].replace({'Prehypertension':'01'},inplace=True)
df['Hypertension'].replace({'Stage 1 hypertension':'10'},inplace=True)
df['Hypertension'].replace({'Stage 2 hypertension':'11'},inplace=True)

# %%
df.sample(10)
# Out:
#      Num.  subject_ID Sex(M/F)  Age(year)  Height(cm)  Weight(kg)  \
# 51     52          67   Female         42         152          49
# 111   112         154   Female         84         162          80
# 169   170         220   Female         55         155          50
# 74     75         108     Male         58         160          65
# 185   186         239     Male         53         175          75
# 123   124         167   Female         57         157          44
# 215   216         416   Female         25         156          47
# 199   200         254   Female         64         150          47
# 94     95         135     Male         56         165          70
# 75     76         110     Male         60         154          50
#
#      Systolic Blood Pressure(mmHg)  Diastolic Blood Pressure(mmHg)  \
# 51                             100                              63
# 111                            149                              70
# ...

# %%
# one_hot_encoded_data = pd.get_dummies(df,columns = ['Hypertension'])
# one_hot_encoded_data
# Out:
#      Num.  subject_ID Sex(M/F)  Age(year)  Height(cm)  Weight(kg)  \
# 0       1           2   Female         45         152          63
# 1       2           3   Female         50         157          50
# 2       3           6   Female         47         150          47
# 3       4           8     Male         45         172          65
# 4       5           9   Female         46         155          65
# ..    ...         ...      ...        ...         ...         ...
# 214   215         415     Male         24         180          70
# 215   216         416   Female         25         156          47
# 216   217         417     Male         25         176          55
# 217   218         418     Male         25         173          63
# 218   219         419     Male         24         175          58
#
#      Systolic Blood Pressure(mmHg)  Diastolic Blood Pressure(mmHg)  \
# 0                              161                              89
# ...

# %%
feature=["BMI(kg/m^2)","Heart Rate(b/m)","Diastolic Blood Pressure(mmHg)","Height(cm)","Weight(kg)","Systolic Blood Pressure(mmHg)"]

# %%
X=df[feature].values

# %%
y=df["Hypertension"].values

# %%
X
# Out:
# array([[ 27.27,  97.  ,  89.  , 152.  ,  63.  , 161.  ],
#        [ 20.28,  76.  ,  93.  , 157.  ,  50.  , 160.  ],
#        [ 20.89,  79.  ,  71.  , 150.  ,  47.  , 101.  ],
#        ...,
#        [ 17.76,  72.  ,  69.  , 176.  ,  55.  , 120.  ],
#        [ 21.05,  67.  ,  69.  , 173.  ,  63.  , 106.  ],
#        [ 18.94,  65.  ,  68.  , 175.  ,  58.  , 108.  ]])

# %%
X.shape
# Out:
# (219, 6)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc_x = StandardScaler()
xtrain = sc_x.fit_transform(X_train) 
xtest = sc_x.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)
classifier.fit(xtrain, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
y_pred = classifier.predict(xtest)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
  
print ("Confusion Matrix : \n", cm)
# Out:
# Confusion Matrix :
#  [[16  0  0  0]
#  [ 2 25  1  0]
#  [ 0  1  8  0]
#  [ 0  0  0  2]]

# %%
from sklearn.metrics import accuracy_score
print ("Accuracy : ", accuracy_score(y_test, y_pred))
# Out:
# Accuracy :  0.9272727272727272

# %%
from sklearn.metrics import precision_recall_fscore_support
precision_recall_fscore_support(y_test, y_pred, average='macro')
# Out:
# (0.9348290598290598, 0.9454365079365079, 0.9389978213507625, None)

# %%
precision_recall_fscore_support(y_test, y_pred, average='weighted')
# Out:
# (0.5509090909090909, 0.5636363636363636, 0.5523232323232323, None)
